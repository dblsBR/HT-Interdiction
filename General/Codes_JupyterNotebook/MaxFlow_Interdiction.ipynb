# %%
import networkx as nx;
#import matplotlib.pyplot as plt
import pandas as pd;
import gurobipy as gp;
from gurobipy import GRB;
import csv;
import sys;
import time;
from datetime import datetime;
import math;
import random;
import itertools;
import numpy as np;

# %%
def MaxFlow_Interdiction (network, budget, T_Limit, summaryName):
    
    start_time = time.time(); 
    networkCSV = network+'.csv';
    
    # Reading network file
    with open(networkCSV, newline='') as f:
        reader = csv.reader(f);
        row1 = next(reader);
        s = int(row1[0]);             # Source node
        t = int(row1[1]);             # Sink node
        calA_level = int(row1[2]);    # Level of special arcs
    
        G = nx.DiGraph();
        data = pd.read_csv(networkCSV, skiprows=1, header=None);
        n_edge = len(data.index+1);
    
        for i in range(n_edge): 
            G.add_edge(data.iat[i,0], data.iat[i,1], capacity= data.iat[i,2], 
                    cost=data.iat[i,3], special=data.iat[i,4], level=data.iat[i,5]);
    
    A = 0;
    U = G.edges[t,s]['capacity'];
    for i,j in G.edges:
        if G.edges[i,j]['special'] == 1:
            A = A + 1;
            
    ### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ###

    
    ### Optimization Model ###
    
    M = A;
    
    
    instance = 'LogFile_'+network+'_b'+str(budget)+'.txt';
    
    model = gp.Model("MaxFlow_Interdiction"); 
    
    gamma = model.addVars(G.edges, vtype=GRB.BINARY); 
    z = model.addVars(G.edges, vtype=GRB.BINARY); 
    x = model.addVars(G.edges, vtype=GRB.CONTINUOUS, lb = 0, ub = GRB.INFINITY);
    theta = model.addVars(G.edges, vtype=GRB.CONTINUOUS, lb = 0, ub = 1); 
    alpha = model.addVars(G.nodes, vtype=GRB.CONTINUOUS, lb = 0, ub = 1); 
    beta = model.addVars(G.edges, vtype=GRB.CONTINUOUS, lb = 0, ub = 1); 
    
    
    model.addConstr(gp.quicksum(G.edges[i,j]['cost']*gamma[i,j] for i,j in G.edges) <= budget);
    
    model.addConstr(gp.quicksum(G.edges[i,j]['capacity']*beta[i,j] for i,j in G.edges) <= x[t,s]);
    
    model.addConstr(alpha[t] - alpha[s] >= 1);
    
    for i,j in G.edges:
        if G.edges[i,j]['special'] == 1:
            model.addConstr(x[i,j] - (1/M)*z[i,j] >= 0);
        
        model.addConstr(alpha[i] - alpha[j] + theta[i,j] >= 0);
        model.addConstr(beta[i,j] + gamma[i,j] - theta[i,j] >= 0);
        model.addConstr(x[i,j] - G.edges[i,j]['capacity']*(1-gamma[i,j]) <= 0);
            
    model.addConstrs(gp.quicksum(x[v,u] for u in G.successors(v)) -
                     gp.quicksum(x[u,v] for u in G.predecessors(v)) == 0 for v in G.nodes);
            
    #model.setObjective(gp.quicksum(G.edges[i,j]['capacity']*beta[i,j] for i,j in G.edges), GRB.MINIMIZE);
    
    model.setObjective(x[t,s], GRB.MINIMIZE);
    
    model.setParam("IntegralityFocus",1);
    #model.setParam("MIPFocus", 3);
    #model.setParam('NodefileStart', 0.5)    # Memore Issues
    #model.setParam("NumericFocus",2);
    model.setParam('TimeLimit', T_Limit); 
    model.update();
    
    model.setParam("LogToConsole", 0)
    model.setParam("OutputFlag", 1);
    model.setParam("LogFile", instance);
    model.optimize();
    
    status = model.status;
    end_time = time.time();
    run_time = round(end_time - start_time, 2);
    
    now = datetime.now();
    
    obj = round(model.objVal);
    LB = model.objBound;
    sol = A - obj;
    OptGap = round(model.MIPGap, 2);
    
    ### ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ####
    
    ### Print to the screen and to result file #######################
    
    file = open('MaxFlowInt_'+network+'_b'+str(budget)+'.txt', "w");
    file.write('Instance: %s, budget %g \n' %(network, budget));
    file.write('Instance executed at: %s \n\n' %now.strftime("%c"));
    
    file.write('Number of Nodes: %g \n' % (t+1));
    file.write('Number of Arcs: %g \n' % G.number_of_edges());
    file.write('Level of special set: %g \n' % calA_level);
    file.write('Budget: %g' % budget +'\n\n');
    
    
    print('\n')
    print('Instance: %s, budget %g\n' %(network, budget));
    if status == 2:
        print('Status: Optimal');
        print('Number of special arcs without flow: %g' % sol);
        print('Number of special arcs with flow: %g' % obj);
        
        file.write('Status: Optimal\n');
        file.write('Number of special arcs without flow: %g \n' % sol);
        file.write('Number of special arcs with flow: %g \n' % obj);
        
    elif status == 9:
        print('Status: Time Limit');
        print('Number of special arcs without flow: %g' % sol);
        print('Number of special arcs with flow: %g' % obj);     
        print('Optimality Gap: %g' % OptGap);
        
        file.write('Status: Time Limit \n');
        file.write('Number of special arcs without flow: %g \n' % sol);
        file.write('Number of special arcs with flow: %g \n' % obj);     
        file.write('Optimality Gap: %g \n' % OptGap);
              
    else:
        print('Status: %g' %status);
        file.write('Status: %g \n' %status);
    
    print('\nMax-Flow: %g \n' %x[t,s].x);
    file.write('Max-Flow: %g \n' %x[t,s].x);
    
    print('run time: %g sec \n' %run_time);
    file.write('run time: %g sec \n' %run_time);
    
    file.write('Level 0 Capacities: %g \n\n ' %G.edges[s,1]['capacity']);
    
    print('Intediction:')
    for i,j in G.edges:
        if gamma[i,j].x > 0.0001:
            print("arc (%g,%g), gamma = %g" %(i,j, gamma[i,j].x));
    print('\n');
    
    
    lev1 = 0;
    lev2 = 0;
    lev3 = 0;
    other_level = 0;
    
    file.write('\nInterdiction plan: \n');
    
    key1 = False;
    key2 = False;
    key3 = False;
    
    for i, j in G.edges: 
        if gamma[i,j].x > 0.0001:
            if G.edges[i,j]["level"] == 1:
                if key1 == False:
                    file.write("Level 1:" +'\n');
                    key1 = True;
                file.write("arc (%g,%g), gamma = %g \n" %(i,j, gamma[i,j].x));
                lev1 += 1;
            elif G.edges[i,j]["level"] == 2:
                if key2 == False:
                    file.write('Level 2: \n');
                    key2 = True;
                file.write("arc (%g,%g), gamma = %g \n" %(i,j, gamma[i,j].x));
                lev2 += 1;
            elif G.edges[i,j]["level"] == 3:
                if key3 == False:
                    file.write('Level 3: \n');
                    key3 = True;
                file.write("arc (%g,%g), gamma = %g \n" %(i,j, gamma[i,j].x));
                lev3 += 1;
            else:
                file.write('Other Levels: \n');
                file.write("arc (%g,%g), gamma = %g \n" %(i,j, gamma[i,j].x));
                other_level += 1;
                
    file.write('\nSpecial arcs with flow : \n');    
    for i, j in G.edges:
        if G.edges[i,j]['special'] == 1:
            if x[i,j].x > 0.0001:
                file.write('Arc (%s,%s), Flow: %f \n' %(i,j, x[i,j].x));
    
    
    
    file.write('\n');
    file.close();
    
    rowFields = [network, budget, calA_level, (t+1), G.number_of_edges(), OptGap, obj, x[t,s].x, lev1, lev2, lev3,
                 other_level, run_time];
    
    with open(summaryName, 'a', newline='') as csvfile:
        csvwriter = csv.writer(csvfile);
        csvwriter.writerow(rowFields);
        csvfile.close();

# %%
n_Networks = 10;
Budget = [0,3,6,9,12];


T_Limit = 3600;


summaryName = "MaxFlowInterdiction_Summary.csv"
file_summary = open(summaryName, "w");
file_summary.write('Instance,Budget,Cal_A,Nodes,Arcs,OptGap,');
file_summary.write('Obj_val,Flow,Lev_1,Lev_2,Lev_3,Other,Time\n');
file_summary.close();

for n in range(1, n_Networks+1):
    network = 'Net'+str(n);
    
    for budget in Budget:
        MaxFlow_Interdiction (network, budget, T_Limit, summaryName);
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-28
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net1, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 16
#
# Max-Flow: 16
#
# run time: 0.09 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net1, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 13
#
# Max-Flow: 13
#
# run time: 0.04 sec
#
# Intediction:
# arc (2,8), gamma = 1
# arc (3,9), gamma = 1
# arc (4,9), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net1, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 6
# Number of special arcs with flow: 10
#
# Max-Flow: 10
#
# run time: 0.04 sec
#
# Intediction:
# arc (2,8), gamma = 1
# arc (4,9), gamma = 1
# arc (6,12), gamma = 1
# arc (6,13), gamma = 1
# arc (6,14), gamma = 1
# arc (6,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net1, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 7
#
# Max-Flow: 7
#
# run time: 0.02 sec
#
# Intediction:
# arc (4,9), gamma = 1
# arc (6,12), gamma = 1
# arc (6,13), gamma = 1
# arc (6,14), gamma = 1
# arc (6,15), gamma = 1
# arc (10,11), gamma = 1
# arc (10,12), gamma = 1
# arc (10,14), gamma = 1
# arc (10,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net1, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 12
# Number of special arcs with flow: 4
#
# Max-Flow: 4
#
# run time: 0.03 sec
#
# Intediction:
# arc (6,12), gamma = 1
# arc (6,13), gamma = 1
# arc (6,14), gamma = 1
# arc (6,15), gamma = 1
# arc (8,11), gamma = 1
# arc (8,13), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
# arc (10,11), gamma = 1
# arc (10,12), gamma = 1
# arc (10,14), gamma = 1
# arc (10,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net2, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 14
#
# Max-Flow: 14
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net2, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 11
#
# Max-Flow: 11
#
# run time: 0.02 sec
#
# Intediction:
# arc (4,8), gamma = 1
# arc (5,6), gamma = 1
# arc (5,7), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net2, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 6
# Number of special arcs with flow: 8
#
# Max-Flow: 8
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,7), gamma = 1
# arc (3,8), gamma = 1
# arc (3,10), gamma = 1
# arc (4,8), gamma = 1
# arc (5,6), gamma = 1
# arc (5,7), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net2, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 5
#
# Max-Flow: 5
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,7), gamma = 1
# arc (2,9), gamma = 1
# arc (3,8), gamma = 1
# arc (3,10), gamma = 1
# arc (4,7), gamma = 1
# arc (4,8), gamma = 1
# arc (4,10), gamma = 1
# arc (5,6), gamma = 1
# arc (5,7), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net2, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 11
# Number of special arcs with flow: 3
#
# Max-Flow: 3
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,7), gamma = 1
# arc (2,9), gamma = 1
# arc (3,10), gamma = 1
# arc (4,7), gamma = 1
# arc (4,10), gamma = 1
# arc (5,6), gamma = 1
# arc (5,7), gamma = 1
# arc (8,11), gamma = 1
# arc (8,12), gamma = 1
# arc (8,13), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net3, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 13
#
# Max-Flow: 13
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net3, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 10
#
# Max-Flow: 10
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,6), gamma = 1
# arc (4,7), gamma = 1
# arc (5,8), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net3, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 6
# Number of special arcs with flow: 7
#
# Max-Flow: 7
#
# run time: 0.02 sec
#
# Intediction:
# arc (3,7), gamma = 1
# arc (5,6), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net3, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 4
#
# Max-Flow: 4
#
# run time: 0.02 sec
#
# Intediction:
# arc (1,7), gamma = 1
# arc (3,6), gamma = 1
# arc (3,7), gamma = 1
# arc (4,10), gamma = 1
# arc (5,6), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net3, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 12
# Number of special arcs with flow: 1
#
# Max-Flow: 1
#
# run time: 0.02 sec
#
# Intediction:
# arc (1,7), gamma = 1
# arc (2,6), gamma = 1
# arc (3,6), gamma = 1
# arc (3,7), gamma = 1
# arc (4,7), gamma = 1
# arc (4,10), gamma = 1
# arc (5,6), gamma = 1
# arc (5,8), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net4, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 5
#
# Max-Flow: 5
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net4, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 5
#
# Max-Flow: 5
#
# run time: 0.03 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net4, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 2
# Number of special arcs with flow: 3
#
# Max-Flow: 3
#
# run time: 0.03 sec
#
# Intediction:
# arc (8,12), gamma = 1
# arc (8,13), gamma = 1
# arc (7,11), gamma = 1
# arc (7,12), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net4, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 2
#
# Max-Flow: 2
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,10), gamma = 1
# arc (7,11), gamma = 1
# arc (7,12), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net4, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 2
#
# Max-Flow: 2
#
# run time: 0.05 sec
#
# Intediction:
# arc (1,8), gamma = 1
# arc (9,11), gamma = 1
# arc (9,15), gamma = 1
# arc (7,11), gamma = 1
# arc (7,12), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net5, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 15
#
# Max-Flow: 15
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net5, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 12
#
# Max-Flow: 12
#
# run time: 0.03 sec
#
# Intediction:
# arc (1,8), gamma = 1
# arc (3,8), gamma = 1
# arc (5,7), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net5, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 5
# Number of special arcs with flow: 10
#
# Max-Flow: 10
#
# run time: 0.03 sec
#
# Intediction:
# arc (5,9), gamma = 1
# arc (8,11), gamma = 1
# arc (8,12), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net5, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 8
# Number of special arcs with flow: 7
#
# Max-Flow: 7
#
# run time: 0.03 sec
#
# Intediction:
# arc (8,11), gamma = 1
# arc (8,12), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
# arc (7,11), gamma = 1
# arc (7,12), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
# arc (7,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net5, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 10
# Number of special arcs with flow: 5
#
# Max-Flow: 5
#
# run time: 0.03 sec
#
# Intediction:
# arc (1,10), gamma = 1
# arc (5,7), gamma = 1
# arc (8,11), gamma = 1
# arc (8,12), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,13), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net6, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 16
#
# Max-Flow: 16
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net6, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 13
#
# Max-Flow: 13
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,9), gamma = 1
# arc (5,6), gamma = 1
# arc (5,10), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net6, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 6
# Number of special arcs with flow: 10
#
# Max-Flow: 10
#
# run time: 0.03 sec
#
# Intediction:
# arc (5,10), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,13), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net6, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 7
#
# Max-Flow: 7
#
# run time: 0.02 sec
#
# Intediction:
# arc (3,6), gamma = 1
# arc (4,8), gamma = 1
# arc (5,6), gamma = 1
# arc (5,10), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,13), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net6, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 11
# Number of special arcs with flow: 5
#
# Max-Flow: 5
#
# run time: 0.04 sec
#
# Intediction:
# arc (2,6), gamma = 1
# arc (2,10), gamma = 1
# arc (3,6), gamma = 1
# arc (4,8), gamma = 1
# arc (5,6), gamma = 1
# arc (5,10), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,13), gamma = 1
# arc (9,14), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net7, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 13
#
# Max-Flow: 13
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net7, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 10
#
# Max-Flow: 10
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,8), gamma = 1
# arc (3,8), gamma = 1
# arc (4,9), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net7, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 5
# Number of special arcs with flow: 8
#
# Max-Flow: 8
#
# run time: 0.04 sec
#
# Intediction:
# arc (2,8), gamma = 1
# arc (3,6), gamma = 1
# arc (3,8), gamma = 1
# arc (4,9), gamma = 1
# arc (5,8), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net7, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 7
# Number of special arcs with flow: 6
#
# Max-Flow: 6
#
# run time: 0.05 sec
#
# Intediction:
# arc (2,8), gamma = 1
# arc (3,6), gamma = 1
# arc (3,8), gamma = 1
# arc (5,8), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,13), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net7, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 4
#
# Max-Flow: 4
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,8), gamma = 1
# arc (3,6), gamma = 1
# arc (3,8), gamma = 1
# arc (3,10), gamma = 1
# arc (4,6), gamma = 1
# arc (5,8), gamma = 1
# arc (9,11), gamma = 1
# arc (9,12), gamma = 1
# arc (9,13), gamma = 1
# arc (9,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net8, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 13
#
# Max-Flow: 13
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net8, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 10
#
# Max-Flow: 10
#
# run time: 0.03 sec
#
# Intediction:
# arc (1,6), gamma = 1
# arc (2,6), gamma = 1
# arc (4,8), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net8, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 7
# Number of special arcs with flow: 6
#
# Max-Flow: 6
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,7), gamma = 1
# arc (3,7), gamma = 1
# arc (6,11), gamma = 1
# arc (6,13), gamma = 1
# arc (6,14), gamma = 1
# arc (6,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net8, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 4
#
# Max-Flow: 4
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,7), gamma = 1
# arc (3,7), gamma = 1
# arc (4,8), gamma = 1
# arc (5,10), gamma = 1
# arc (6,11), gamma = 1
# arc (6,13), gamma = 1
# arc (6,14), gamma = 1
# arc (6,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net8, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 11
# Number of special arcs with flow: 2
#
# Max-Flow: 2
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,7), gamma = 1
# arc (3,7), gamma = 1
# arc (4,8), gamma = 1
# arc (6,11), gamma = 1
# arc (6,13), gamma = 1
# arc (6,14), gamma = 1
# arc (6,15), gamma = 1
# arc (10,11), gamma = 1
# arc (10,12), gamma = 1
# arc (10,13), gamma = 1
# arc (10,14), gamma = 1
# arc (10,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net9, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 18
#
# Max-Flow: 18
#
# run time: 0.02 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net9, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 15
#
# Max-Flow: 15
#
# run time: 0.03 sec
#
# Intediction:
# arc (1,10), gamma = 1
# arc (2,9), gamma = 1
# arc (4,9), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net9, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 7
# Number of special arcs with flow: 11
#
# Max-Flow: 11
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,9), gamma = 1
# arc (4,9), gamma = 1
# arc (10,11), gamma = 1
# arc (10,12), gamma = 1
# arc (10,14), gamma = 1
# arc (10,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net9, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 10
# Number of special arcs with flow: 8
#
# Max-Flow: 8
#
# run time: 0.03 sec
#
# Intediction:
# arc (5,7), gamma = 1
# arc (8,11), gamma = 1
# arc (8,12), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
# arc (10,11), gamma = 1
# arc (10,12), gamma = 1
# arc (10,14), gamma = 1
# arc (10,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net9, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 12
# Number of special arcs with flow: 6
#
# Max-Flow: 6
#
# run time: 0.04 sec
#
# Intediction:
# arc (2,9), gamma = 1
# arc (4,9), gamma = 1
# arc (5,7), gamma = 1
# arc (6,12), gamma = 1
# arc (8,11), gamma = 1
# arc (8,12), gamma = 1
# arc (8,14), gamma = 1
# arc (8,15), gamma = 1
# arc (10,11), gamma = 1
# arc (10,12), gamma = 1
# arc (10,14), gamma = 1
# arc (10,15), gamma = 1
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net10, budget 0
#
# Status: Optimal
# Number of special arcs without flow: 0
# Number of special arcs with flow: 17
#
# Max-Flow: 17
#
# run time: 0.03 sec
#
# Intediction:
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net10, budget 3
#
# Status: Optimal
# Number of special arcs without flow: 3
# Number of special arcs with flow: 14
#
# Max-Flow: 14
#
# run time: 0.03 sec
#
# Intediction:
# arc (1,7), gamma = 1
# arc (2,9), gamma = 1
# arc (5,7), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net10, budget 6
#
# Status: Optimal
# Number of special arcs without flow: 6
# Number of special arcs with flow: 11
#
# Max-Flow: 11
#
# run time: 0.02 sec
#
# Intediction:
# arc (2,9), gamma = 1
# arc (3,9), gamma = 1
# arc (7,11), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
# arc (7,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net10, budget 9
#
# Status: Optimal
# Number of special arcs without flow: 9
# Number of special arcs with flow: 8
#
# Max-Flow: 8
#
# run time: 0.05 sec
#
# Intediction:
# arc (2,9), gamma = 1
# arc (3,6), gamma = 1
# arc (3,8), gamma = 1
# arc (3,9), gamma = 1
# arc (3,10), gamma = 1
# arc (7,11), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
# arc (7,15), gamma = 1
#
#
# Set parameter IntegralityFocus to value 1
# Set parameter TimeLimit to value 3600
#
#
# Instance: Net10, budget 12
#
# Status: Optimal
# Number of special arcs without flow: 11
# Number of special arcs with flow: 6
#
# Max-Flow: 6
#
# run time: 0.03 sec
#
# Intediction:
# arc (2,6), gamma = 1
# arc (2,9), gamma = 1
# arc (3,6), gamma = 1
# arc (3,8), gamma = 1
# arc (3,9), gamma = 1
# arc (3,10), gamma = 1
# arc (4,8), gamma = 1
# arc (7,11), gamma = 1
# arc (7,13), gamma = 1
# arc (7,14), gamma = 1
# arc (7,15), gamma = 1
